# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# ### Contents:
#
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Problem Statement
#
# Define the problem you are finding answers for from the data given.

# %% [markdown]
# #### Import libraries

# %%
#Imports:
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from string import digits

sns.set_style('whitegrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read in SAT and ACT Data

# %%
sat_2017 = pd.read_csv('../data/sat_2017.csv')
act_2017 = pd.read_csv("../data/act_2017_updated.csv")

# %% [markdown]
# #### 2 and 3. Display and describe data

# %% [markdown]
# Function to display data and information regarding data

# %%
def func_display_describe_data(data):
    no_rows = data.shape[0]
    no_cols = data.shape[1]
    col_list = data.columns
    
    print('Number of rows: {}'.format(no_rows))
    print('Number of columns: {}\n'.format(no_cols))
    print('Column headers: {}\n'.format(col_list))
    print("There are {} NaNs in the dataframe.\n".format(data.isnull().sum().sum()))
    print(data.describe())
    print(data.info())
    return data.head(10)

# %%
# Displaying sat_2017 data
func_display_describe_data(sat_2017)
# Out:
# Number of rows: 51
# Number of columns: 5
#
# Column headers: Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')
#
# There are 0 NaNs in the dataframe.
#
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB
# None
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# 8   468    950
# 9   497   1017

# %%
# Displaying  act_2017 data
func_display_describe_data(act_2017)
# Out:
# Number of rows: 52
# Number of columns: 7
#
# Column headers: Index(['State', 'Participation', 'Composite', 'English', 'Mathematics',
#        'Reading', 'Science'],
#       dtype='object')
#
# There are 0 NaNs in the dataframe.
#
#        Participation  Composite    English  Mathematics    Reading    Science
# count      52.000000  52.000000  52.000000    52.000000  52.000000  52.000000
# mean       65.153846  21.509615  20.919231    21.173077  22.001923  21.442308
# std        31.832518   2.002083   2.332132     1.963602   2.048672   1.723351
# min         8.000000  17.800000  16.300000    18.000000  18.100000  18.200000
# 25%        31.000000  19.800000  19.000000    19.400000  20.475000  19.975000
# 50%        68.000000  21.400000  20.550000    20.900000  21.700000  21.300000
# 75%       100.000000  23.600000  23.300000    23.100000  24.125000  23.200000
# max       100.000000  25.500000  25.500000    25.300000  26.000000  24.900000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null int64
# Composite        52 non-null float64
# English          52 non-null float64
# Mathematics      52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.0+ KB
# None
#                   State  Participation  Composite  English  Mathematics  \
# 0               Alabama            100       19.2     18.9         18.4
# 1                Alaska             65       19.8     18.7         19.8
# 2               Arizona             62       19.7     18.6         19.8
# 3              Arkansas            100       19.4     18.9         19.0
# 4            California             31       22.8     22.5         22.7
# 5              Colorado            100       20.8     20.1         20.3
# 6           Connecticut             31       25.2     25.5         24.6
# 7              Delaware             18       24.1     24.1         23.4
# 8  District of Columbia             32       24.2     24.4         23.5
# 9               Florida             73       19.8     19.0         19.4
#
#    Reading  Science
# 0     19.7     19.4
# 1     20.4     19.9
# 2     20.1     19.8
# 3     19.7     19.5
# 4     23.1     22.2
# 5     21.2     20.9
# 6     25.6     24.6
# 7     24.8     23.6
# 8     24.9     23.5
# 9     21.0     19.4

# %% [markdown]
# #### 4a. Check if data is complete

# %% [markdown]
# - The data does look complete as there are no missing/ null entries.
# - However ACT data contains 52 rows while SAT row only contains 51 rows
#     - ACT contains a "National" row which SAT does not contain

# %%
# Thus, we are removing the "National" row from act_2017 and saving it separately as act_national
act_national = act_2017.loc[act_2017["State"] == "National"]
act_2017.drop(0, axis=0, inplace=True)

# %%
act_national
#func_display_describe_data(act_2017) 

# Now if we view dataframe, we will only have 51 rows
# Out:
#        State  Participation  Composite  English  Mathematics  Reading  Science
# 51  National             60       21.0     20.3         20.7     21.4     21.0

# %% [markdown]
# #### 4b. Check for any obvious issues with the observations

# %% [markdown]
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
#     - The Evidence-Based Reading and Writing (EBRW) and Math sections each use a scale of 200-800 and are combined for a total score. --> the minimum of math is beyond the lowest possible at 52.
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)
#     - Each section uses a scale of 1-36. Your total score is the average of your four section scores.

# %% [markdown]
# - sat_sections = ["Math", "Evidence-Based Reading and Writing"]
# - act_sections = ["Mathematics", "English", "Reading", "Science"]

# %%
# The minimum of math is beyond the lowest possible at 52
sat_2017[20:21]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %%
# Fixing the issue for sat_2017
sat_2017['Math'][20:21] = 524
sat_2017[20:21]
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536   524   1060

# %%
#Ensuring consistency of data

# SAT sections should add up to SAT total - since there are many with 1 diff, we are only taking the state with >1 difference
check_sat = abs(sat_2017.Math + sat_2017["Evidence-Based Reading and Writing"] - sat_2017.Total)  
check_sat   #check_sat should be zero

print("For SAT scores:")
for ix,val in check_sat.items():  
    if val > 1:
        print("State {} ({}): Total SAT score differ from indiv scores by = {}".format(ix, sat_2017.loc[ix,'State'], val))
        
# ACT sections should add up to 4* the composite score - since there are many with 0.something difference, we are only taking those with >1 differenece
check_act = abs(act_2017.English + act_2017.Mathematics + act_2017.Reading + act_2017.Science - 4*act_2017.Composite)
check_act                
print("For ACT scores:")
for ix, val in check_act.items():
    if val > 1:
        print("State {} ({}): Total ACT score differ from indiv scores by = {}".format(ix, act_2017.loc[ix,'State'], val))
# Out:
# For SAT scores:
# For ACT scores:

# %% [markdown]
# #### 5. Check datatype of each feature

# %%
print("FOR SAT SCORE:\n", sat_2017.dtypes,'\n')
print("FOR ACT SCORE:\n", act_2017.dtypes)
# Out:
# FOR SAT SCORE:
#  State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
#
# FOR ACT SCORE:
#  State             object
# Participation      int64
# Composite        float64
# English          float64
# Mathematics      float64
# Reading          float64
# Science          float64
# dtype: object

# %% [markdown]
# Participation is a object, while for analysis we will need it to be a number

# %% [markdown]
# #### 6. Fix incorrect data type(s)

# %%
# Removing '%' from Participation values and turning them to float
sat_2017['Participation'] = sat_2017['Participation'].map(lambda x: x.replace('%',''))
sat_2017['Participation'] = sat_2017['Participation'].astype(float)

act_2017['Participation'] = act_2017['Participation'].astype(float)

# %%
# Checking datatypes again

print("FOR SAT SCORE:\n", sat_2017.dtypes,'\n')
print("FOR ACT SCORE:\n", act_2017.dtypes)
# Out:
# FOR SAT SCORE:
#  State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object
#
# FOR ACT SCORE:
#  State             object
# Participation    float64
# Composite        float64
# English          float64
# Mathematics      float64
# Reading          float64
# Science          float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns

# %% [markdown]
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
print("sat columns: ", sat_2017.columns, "\n",
"act columns: ",act_2017.columns)
# Out:
# sat columns:  Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')
#  act columns:  Index(['State', 'Participation', 'Composite', 'English', 'Mathematics',
#        'Reading', 'Science'],
#       dtype='object')

# %%
# Renaming for sat 2017
sat_2017.rename(columns= {'State': 'state',
                         'Participation': 'participation_sat17',
                         'Evidence-Based Reading and Writing': 'ebrw_sat17',
                         'Math': 'math_sat17',
                         'Total': 'total_sat17'}, inplace = True)
sat_2017.head()
# Out:
#         state  participation_sat17  ebrw_sat17  math_sat17  total_sat17
# 0     Alabama                  5.0         593         572         1165
# 1      Alaska                 38.0         547         533         1080
# 2     Arizona                 30.0         563         553         1116
# 3    Arkansas                  3.0         614         594         1208
# 4  California                 53.0         531         524         1055

# %%
# Renaming for act 2017
act_2017.rename(columns = {'State': 'state',
                          'Participation': 'participation_act17',
                          'Composite': 'composite_act17',
                          'English': 'english_act17',
                          'Mathematics': 'math_act17',
                          'Reading': 'reading_act17',
                          'Science':'science_act17'}, inplace = True)
act_2017.head()
# Out:
#         state  participation_act17  composite_act17  english_act17  \
# 1      Alaska                 65.0             19.8           18.7
# 2     Arizona                 62.0             19.7           18.6
# 3    Arkansas                100.0             19.4           18.9
# 4  California                 31.0             22.8           22.5
# 5    Colorado                100.0             20.8           20.1
#
#    math_act17  reading_act17  science_act17
# 1        19.8           20.4           19.9
# 2        19.8           20.1           19.8
# 3        19.0           19.7           19.5
# 4        22.7           23.1           22.2
# 5        20.3           21.2           20.9

# %% [markdown]
# #### 8. Creating a data dictionary

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT/SAT|This column contains all the states|
# |participation_sat17|float|SAT|The participation % for SAT per state|
# |ebrw_sat17|int|SAT|The score for Evidence-Based Reading and Writing for SAT per state|
# |math_sat17|int|SAT|The score for Math for SAT per state|
# |total_sat17|int|SAT|The total SAT score per state|
# |participation_act17|float|ACT|The participation % for SAT per state|
# |composite_act17|float|ACT|The average score for ACT per state|
# |english_act17|float|ACT|The score for English for ACT per state|
# |math_act17|float|ACT|The score for Math for ACT per state|
# |reading_act17|float|ACT|The score for Reading for ACT per state|
# |science_act17|float|ACT|The score for Science for ACT per state|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# - Done previously

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
act_sat_2017 = pd.merge(sat_2017, act_2017, on='state')
act_sat_2017.head()
# Out:
#         state  participation_sat17  ebrw_sat17  math_sat17  total_sat17  \
# 0      Alaska                 38.0         547         533         1080
# 1     Arizona                 30.0         563         553         1116
# 2    Arkansas                  3.0         614         594         1208
# 3  California                 53.0         531         524         1055
# 4    Colorado                 11.0         606         595         1201
#
#    participation_act17  composite_act17  english_act17  math_act17  \
# 0                 65.0             19.8           18.7        19.8
# 1                 62.0             19.7           18.6        19.8
# 2                100.0             19.4           18.9        19.0
# 3                 31.0             22.8           22.5        22.7
# 4                100.0             20.8           20.1        20.3
#
#    reading_act17  science_act17
# 0           20.4           19.9
# 1           20.1           19.8
# 2           19.7           19.5
# 3           23.1           22.2
# 4           21.2           20.9

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
act_sat_2017.to_csv('../data/combined_2017.csv', index = True)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# #### 1. Run the above steps for 2018 data

# %%
# Reading in csv data
act_2018 = pd.read_csv("../data/act_2018_updated.csv")
sat_2018 = pd.read_csv("../data/sat_2018.csv")

# %%
# func_display_describe_data(sat_2018)

# %%
#func_display_describe_data(act_2018)

# %%
sat_2018['Participation'] = sat_2018['Participation'].map(lambda x: x.replace('%',''))
sat_2018['Participation'] = sat_2018['Participation'].astype(float)

# %%
sat_2018.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6.0                                 595   571   1166
# 1      Alaska           43.0                                 562   544   1106
# 2     Arizona           29.0                                 577   572   1149
# 3    Arkansas            5.0                                 592   576   1169
# 4  California           60.0                                 540   536   1076

# %%
act_2018.head()
# Out:
#         State  Percentage of Students Tested  Average Composite Score  \
# 0     Alabama                            100                     19.1
# 1      Alaska                             33                     20.8
# 2     Arizona                             66                     19.2
# 3    Arkansas                            100                     19.4
# 4  California                             27                     22.7
#
#    Average English Score  Average Math Score  Average Reading Score  \
# 0                   18.9                18.3                   19.6
# 1                   19.8                20.6                   21.6
# 2                   18.2                19.4                   19.5
# 3                   19.1                18.9                   19.7
# 4                   22.5                22.5                   23.0
#
#    Average Science Score
# 0                   19.0
# 1                   20.7
# 2                   19.2
# 3                   19.4
# 4                   22.1

# %%
# Checking for datatypes

print("FOR SAT SCORE:\n", sat_2018.dtypes,'\n')
print("FOR ACT SCORE:\n", act_2018.dtypes)
# Out:
# FOR SAT SCORE:
#  State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object
#
# FOR ACT SCORE:
#  State                             object
# Percentage of Students Tested      int64
# Average Composite Score          float64
# Average English Score            float64
# Average Math Score               float64
# Average Reading Score            float64
# Average Science Score            float64
# dtype: object

# %%
sat_2018.rename(columns= {'State': 'state',
                         'Participation': 'participation_sat18',
                         'Evidence-Based Reading and Writing': 'ebrw_sat18',
                         'Math': 'math_sat18',
                         'Total': 'total_sat18'}, inplace = True)
sat_2018.head()
# Out:
#         state  participation_sat18  ebrw_sat18  math_sat18  total_sat18
# 0     Alabama                  6.0         595         571         1166
# 1      Alaska                 43.0         562         544         1106
# 2     Arizona                 29.0         577         572         1149
# 3    Arkansas                  5.0         592         576         1169
# 4  California                 60.0         540         536         1076

# %%
act_2018.rename(columns = {'State': 'state',
                          'Percentage of Students Tested': 'participation_act18',
                          'Average Composite Score': 'composite_act18',
                          'Average English Score': 'english_act18',
                          'Average Math Score': 'math_act18',
                          'Average Reading Score': 'reading_act18',
                          'Average Science Score':'science_act18'}, inplace = True)
act_2018.head()
# Out:
#         state  participation_act18  composite_act18  english_act18  \
# 0     Alabama                  100             19.1           18.9
# 1      Alaska                   33             20.8           19.8
# 2     Arizona                   66             19.2           18.2
# 3    Arkansas                  100             19.4           19.1
# 4  California                   27             22.7           22.5
#
#    math_act18  reading_act18  science_act18
# 0        18.3           19.6           19.0
# 1        20.6           21.6           20.7
# 2        19.4           19.5           19.2
# 3        18.9           19.7           19.4
# 4        22.5           23.0           22.1

# %%
act_sat_2018 = pd.merge(sat_2018, act_2018, on='state')
act_sat_2018.head()
# Out:
#         state  participation_sat18  ebrw_sat18  math_sat18  total_sat18  \
# 0     Alabama                  6.0         595         571         1166
# 1      Alaska                 43.0         562         544         1106
# 2     Arizona                 29.0         577         572         1149
# 3    Arkansas                  5.0         592         576         1169
# 4  California                 60.0         540         536         1076
#
#    participation_act18  composite_act18  english_act18  math_act18  \
# 0                  100             19.1           18.9        18.3
# 1                   33             20.8           19.8        20.6
# 2                   66             19.2           18.2        19.4
# 3                  100             19.4           19.1        18.9
# 4                   27             22.7           22.5        22.5
#
#    reading_act18  science_act18
# 0           19.6           19.0
# 1           21.6           20.7
# 2           19.5           19.2
# 3           19.7           19.4
# 4           23.0           22.1

# %% [markdown]
# #### 2. Merge 2017 and 2018 data together

# %%
act_sat_1718 = pd.merge(act_sat_2017, act_sat_2018, on='state')
act_sat_1718.head()
# Out:
#         state  participation_sat17  ebrw_sat17  math_sat17  total_sat17  \
# 0      Alaska                 38.0         547         533         1080
# 1     Arizona                 30.0         563         553         1116
# 2    Arkansas                  3.0         614         594         1208
# 3  California                 53.0         531         524         1055
# 4    Colorado                 11.0         606         595         1201
#
#    participation_act17  composite_act17  english_act17  math_act17  \
# 0                 65.0             19.8           18.7        19.8
# 1                 62.0             19.7           18.6        19.8
# 2                100.0             19.4           18.9        19.0
# 3                 31.0             22.8           22.5        22.7
# 4                100.0             20.8           20.1        20.3
#
#    reading_act17  ...  participation_sat18  ebrw_sat18  math_sat18  \
# 0           20.4  ...                 43.0         562         544
# 1           20.1  ...                 29.0         577         572
# 2           19.7  ...                  5.0         592         576
# 3           23.1  ...                 60.0         540         536
# 4           21.2  ...                100.0         519         506
#
#    total_sat18  participation_act18  composite_act18  english_act18  \
# 0         1106                   33             20.8           19.8
# 1         1149                   66             19.2           18.2
# 2         1169                  100             19.4           19.1
# 3         1076                   27             22.7           22.5
# 4         1025                   30             23.9           23.9
#
#    math_act18  reading_act18  science_act18
# 0        20.6           21.6           20.7
# 1        19.4           19.5           19.2
# 2        18.9           19.7           19.4
# 3        22.5           23.0           22.1
# 4        23.2           24.4           23.5
#
# [5 rows x 21 columns]

# %% [markdown]
# #### 3. Save your cleaned merged final dataframe

# %%
act_sat_1718.to_csv('../data/final_2017.csv', index = True)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Summary Statistics

# %%
act_sat_1718.describe()
# Out:
#        participation_sat17  ebrw_sat17  math_sat17  total_sat17  \
# count            50.000000   50.000000   50.000000    50.000000
# mean             40.500000  568.640000  556.580000  1125.320000
# std              35.279207   46.001668   47.549798    93.265134
# min               2.000000  482.000000  468.000000   950.000000
# 25%               4.000000  532.750000  523.250000  1055.250000
# 50%              40.500000  558.500000  544.500000  1104.500000
# 75%              66.500000  613.500000  601.000000  1214.000000
# max             100.000000  644.000000  651.000000  1295.000000
#
#        participation_act17  composite_act17  english_act17  math_act17  \
# count            50.000000        50.000000       50.00000   50.000000
# mean             64.560000        21.566000       20.97200   21.238000
# std              32.077814         2.013588        2.35944    1.961454
# min               8.000000        17.800000       16.30000   18.000000
# 25%              31.000000        19.850000       19.10000   19.500000
# 50%              68.000000        21.400000       20.80000   21.050000
# 75%             100.000000        23.600000       23.30000   23.100000
# max             100.000000        25.500000       25.50000   25.300000
#
#        reading_act17  science_act17  participation_sat18  ebrw_sat18  \
# count      50.000000      50.000000            50.000000    50.00000
# mean       22.060000      21.492000            46.540000   563.06000
# std         2.061404       1.731914            37.254344    47.77174
# min        18.100000      18.200000             2.000000   480.00000
# 25%        20.500000      20.025000             4.250000   534.25000
# 50%        21.850000      21.400000            53.500000   551.00000
# 75%        24.175000      23.200000            78.250000   612.75000
# max        26.000000      24.900000           100.000000   643.00000
#
#        math_sat18  total_sat18  participation_act18  composite_act18  \
# count   50.000000    50.000000            50.000000        50.000000
# mean   555.940000  1119.100000            60.880000        21.534000
# std     48.210597    94.879354            33.979369         2.099622
# min    480.000000   977.000000             7.000000        17.700000
# 25%    522.250000  1055.250000            27.750000        20.000000
# 50%    543.500000  1096.000000            65.500000        21.300000
# 75%    594.250000  1207.000000           100.000000        23.575000
# max    655.000000  1298.000000           100.000000        25.600000
#
#        english_act18  math_act18  reading_act18  science_act18
# count      50.000000   50.000000      50.000000      50.000000
# mean       21.030000   21.182000      22.064000      21.392000
# std         2.452758    2.015622       2.161326       1.858553
# min        16.600000   17.800000      18.000000      17.900000
# 25%        19.125000   19.475000      20.525000      20.000000
# 50%        20.400000   20.800000      21.650000      21.250000
# 75%        23.700000   23.175000      24.150000      23.075000
# max        26.000000   25.200000      26.100000      24.900000

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
def my_std(values):
    mu = np.mean(values)
    return np.sqrt(sum([(v-mu)**2 for v in values])/len(values))

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
# The loop method

std_dict = {}
for ix in act_sat_1718.columns[1:]:
    #print(ix)
    std_dict[ix] = my_std(act_sat_1718[ix])
    
std_dict
# Out:
# {'participation_sat17': 34.92463314052132,
#  'ebrw_sat17': 45.539328058283864,
#  'math_sat17': 47.07189819839434,
#  'total_sat17': 92.32777263640664,
#  'participation_act17': 31.755415286215364,
#  'composite_act17': 1.9933499441894291,
#  'english_act17': 2.3357260113292395,
#  'math_act17': 1.9417404563947267,
#  'reading_act17': 2.0406861591141348,
#  'science_act17': 1.7145075094615363,
#  'participation_sat18': 36.879918655007906,
#  'ebrw_sat18': 47.29161024959924,
#  'math_sat18': 47.72605577669287,
#  'total_sat18': 93.9257685622002,
#  'participation_act18': 33.63785962275246,
#  'composite_act18': 2.0785196655312164,
#  'english_act18': 2.428106257971426,
#  'math_act18': 1.9953636260090541,
#  'reading_act18': 2.13960370162327,
#  'science_act18': 1.8398739087230949}

# %%
{col.name: std_dict(col)  for my_std(act_sat_1718[ix]) for ix in act_sat_1718.columns[1:]}
# Out:
#   File "<ipython-input-181-cfd2ee8f6fb6>", line 1
#     {std_dict(ix) for my_std(act_sat_1718[ix]) for ix in act_sat_1718.columns[1:]}
#                                                  ^
# SyntaxError: invalid syntax

# %%
# The dictionary comprehension method

{col.name:my_std(col) for col in [act_sat_1718[i] for i in act_sat_1718.columns if (act_sat_1718[i].dtype=='float64') or (act_sat_1718[i].dtype=='int64')]}
# Out:
# {'participation_sat17': 34.92463314052132,
#  'ebrw_sat17': 45.539328058283864,
#  'math_sat17': 47.07189819839434,
#  'total_sat17': 92.32777263640664,
#  'participation_act17': 31.755415286215364,
#  'composite_act17': 1.9933499441894291,
#  'english_act17': 2.3357260113292395,
#  'math_act17': 1.9417404563947267,
#  'reading_act17': 2.0406861591141348,
#  'science_act17': 1.7145075094615363,
#  'participation_sat18': 36.879918655007906,
#  'ebrw_sat18': 47.29161024959924,
#  'math_sat18': 47.72605577669287,
#  'total_sat18': 93.9257685622002,
#  'participation_act18': 33.63785962275246,
#  'composite_act18': 2.0785196655312164,
#  'english_act18': 2.428106257971426,
#  'math_act18': 1.9953636260090541,
#  'reading_act18': 2.13960370162327,
#  'science_act18': 1.8398739087230949}

# %%
# Rearranging columns and saving them to another variable - actsat_1718
actsat_1718 = act_sat_1718[['state','participation_sat17','ebrw_sat17', 'math_sat17',
       'total_sat17', 'participation_act17', 'english_act17', 'math_act17', 'reading_act17', 'science_act17', 'composite_act17','participation_sat18', 'ebrw_sat18', 'math_sat18', 'total_sat18',
       'participation_act18','english_act18', 'math_act18',
       'reading_act18', 'science_act18', 'composite_act18']]
actsat_1718.head()
# Out:
#         state  participation_sat17  ebrw_sat17  math_sat17  total_sat17  \
# 0      Alaska                 38.0         547         533         1080
# 1     Arizona                 30.0         563         553         1116
# 2    Arkansas                  3.0         614         594         1208
# 3  California                 53.0         531         524         1055
# 4    Colorado                 11.0         606         595         1201
#
#    participation_act17  english_act17  math_act17  reading_act17  \
# 0                 65.0           18.7        19.8           20.4
# 1                 62.0           18.6        19.8           20.1
# 2                100.0           18.9        19.0           19.7
# 3                 31.0           22.5        22.7           23.1
# 4                100.0           20.1        20.3           21.2
#
#    science_act17  ...  participation_sat18  ebrw_sat18  math_sat18  \
# 0           19.9  ...                 43.0         562         544
# 1           19.8  ...                 29.0         577         572
# 2           19.5  ...                  5.0         592         576
# 3           22.2  ...                 60.0         540         536
# 4           20.9  ...                100.0         519         506
#
#    total_sat18  participation_act18  english_act18  math_act18  reading_act18  \
# 0         1106                   33           19.8        20.6           21.6
# 1         1149                   66           18.2        19.4           19.5
# 2         1169                  100           19.1        18.9           19.7
# 3         1076                   27           22.5        22.5           23.0
# 4         1025                   30           23.9        23.2           24.4
#
#    science_act18  composite_act18
# 0           20.7             20.8
# 1           19.2             19.2
# 2           19.4             19.4
# 3           22.1             22.7
# 4           23.5             23.9
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:

# %%
actsat_1718.head()
# Out:
#         state  participation_sat17  ebrw_sat17  math_sat17  total_sat17  \
# 0      Alaska                 38.0         547         533         1080
# 1     Arizona                 30.0         563         553         1116
# 2    Arkansas                  3.0         614         594         1208
# 3  California                 53.0         531         524         1055
# 4    Colorado                 11.0         606         595         1201
#
#    participation_act17  english_act17  math_act17  reading_act17  \
# 0                 65.0           18.7        19.8           20.4
# 1                 62.0           18.6        19.8           20.1
# 2                100.0           18.9        19.0           19.7
# 3                 31.0           22.5        22.7           23.1
# 4                100.0           20.1        20.3           21.2
#
#    science_act17  ...  participation_sat18  ebrw_sat18  math_sat18  \
# 0           19.9  ...                 43.0         562         544
# 1           19.8  ...                 29.0         577         572
# 2           19.5  ...                  5.0         592         576
# 3           22.2  ...                 60.0         540         536
# 4           20.9  ...                100.0         519         506
#
#    total_sat18  participation_act18  english_act18  math_act18  reading_act18  \
# 0         1106                   33           19.8        20.6           21.6
# 1         1149                   66           18.2        19.4           19.5
# 2         1169                  100           19.1        18.9           19.7
# 3         1076                   27           22.5        22.5           23.0
# 4         1025                   30           23.9        23.2           24.4
#
#    science_act18  composite_act18
# 0           20.7             20.8
# 1           19.2             19.2
# 2           19.4             19.4
# 3           22.1             22.7
# 4           23.5             23.9
#
# [5 rows x 21 columns]

# %% [markdown]
# - Which states have the highest and lowest participation rates for the:

# %% [markdown]
# **2017 SAT**

# %%
#showing only the state and participation_sat17 columns
p_sat17 = actsat_1718.loc[:,['state','participation_sat17']]
p_sat17.head()
# Out:
#         state  participation_sat17
# 0      Alaska                 38.0
# 1     Arizona                 30.0
# 2    Arkansas                  3.0
# 3  California                 53.0
# 4    Colorado                 11.0

# %%
# Getting the unique values for scores to find the top 3 and bottom 3 
x = np.unique(p_sat17['participation_sat17'])
print("top 3 participation rates are (%): ", x[-3:])
print("bottom 3 participation rates are (%): ", x[:3])

p_sat17_low = p_sat17[p_sat17['participation_sat17'] <= x[2]].sort_values(by=['participation_sat17'], ascending = False)
p_sat17_high = p_sat17[p_sat17['participation_sat17'] >= x[-3]].sort_values(by=['participation_sat17'], ascending = False)
# Out:
# top 3 participation rates are (%):  [ 95.  96. 100.]
# bottom 3 participation rates are (%):  [2. 3. 4.]

# %%
# States based on top 3 participation rate in sat 2017
p_sat17_high
# Out:
#                    state  participation_sat17
# 5            Connecticut                100.0
# 6               Delaware                100.0
# 7   District of Columbia                100.0
# 21              Michigan                100.0
# 28         New Hampshire                 96.0
# 18                 Maine                 95.0

# %%
# States based on bottom 3 participation rate in sat 2017
p_sat17_low
# Out:
#            state  participation_sat17
# 15        Kansas                  4.0
# 16      Kentucky                  4.0
# 17     Louisiana                  4.0
# 2       Arkansas                  3.0
# 22     Minnesota                  3.0
# 24      Missouri                  3.0
# 26      Nebraska                  3.0
# 40  South Dakota                  3.0
# 43          Utah                  3.0
# 48     Wisconsin                  3.0
# 49       Wyoming                  3.0
# 14          Iowa                  2.0
# 23   Mississippi                  2.0
# 33  North Dakota                  2.0

# %% [markdown]
# **2018 SAT**

# %%
p_sat18 = actsat_1718.loc[:,['state','participation_sat18']]
p_sat18.head()
# Out:
#         state  participation_sat18
# 0      Alaska                 43.0
# 1     Arizona                 29.0
# 2    Arkansas                  5.0
# 3  California                 60.0
# 4    Colorado                100.0

# %%
# Getting the unique values for scores to find the top 3 and bottom 3 
x = np.unique(p_sat18['participation_sat18'])
print("top 3 participation rates are (%): ", x[-3:])
print("bottom 3 participation rates are (%): ", x[:3])

p_sat18_low = p_sat18[p_sat18['participation_sat18'] <= x[2]].sort_values(by=['participation_sat18'], ascending = False)
p_sat18_high = p_sat18[p_sat18['participation_sat18'] >= x[-3]].sort_values(by=['participation_sat18'], ascending = False)
# Out:
# top 3 participation rates are (%):  [ 97.  99. 100.]
# bottom 3 participation rates are (%):  [2. 3. 4.]

# %%
# States based on top 3 participation rate in sat 2018
p_sat18_high
# Out:
#            state  participation_sat18
# 4       Colorado                100.0
# 5    Connecticut                100.0
# 6       Delaware                100.0
# 11         Idaho                100.0
# 21      Michigan                100.0
# 12      Illinois                 99.0
# 18         Maine                 99.0
# 38  Rhode Island                 97.0

# %%
# States based on bottom 3 participation rate in sat 2018
p_sat18_low
# Out:
#            state  participation_sat18
# 15        Kansas                  4.0
# 16      Kentucky                  4.0
# 17     Louisiana                  4.0
# 22     Minnesota                  4.0
# 24      Missouri                  4.0
# 43          Utah                  4.0
# 14          Iowa                  3.0
# 23   Mississippi                  3.0
# 26      Nebraska                  3.0
# 40  South Dakota                  3.0
# 48     Wisconsin                  3.0
# 49       Wyoming                  3.0
# 33  North Dakota                  2.0

# %% [markdown]
# **2017 ACT**

# %%
p_act17 = actsat_1718.loc[:,['state','participation_act17']]
p_act17.head()
# Out:
#         state  participation_act17
# 0      Alaska                 65.0
# 1     Arizona                 62.0
# 2    Arkansas                100.0
# 3  California                 31.0
# 4    Colorado                100.0

# %%
# Getting the unique values for scores to find the top 3 and bottom 3 
x = np.unique(p_act17['participation_act17'])
print("top 3 participation rates are (%): ", x[-3:])
print("bottom 3 participation rates are (%): ", x[:3])

p_act17_low = p_act17[p_act17['participation_act17'] <= x[2]].sort_values(by=['participation_act17'], ascending = False)
p_act17_high = p_act17[p_act17['participation_act17'] >= x[-3]].sort_values(by=['participation_act17'], ascending = False)
# Out:
# top 3 participation rates are (%):  [ 93.  98. 100.]
# bottom 3 participation rates are (%):  [ 8. 18. 21.]

# %%
# States based on top 3 participation rate in act 2017
p_act17_high
# Out:
#              state  participation_act17
# 2         Arkansas                100.0
# 4         Colorado                100.0
# 48       Wisconsin                100.0
# 43            Utah                100.0
# 41       Tennessee                100.0
# 39  South Carolina                100.0
# 35        Oklahoma                100.0
# 32  North Carolina                100.0
# 27          Nevada                100.0
# 25         Montana                100.0
# 24        Missouri                100.0
# 23     Mississippi                100.0
# 22       Minnesota                100.0
# 17       Louisiana                100.0
# 16        Kentucky                100.0
# 49         Wyoming                100.0
# 33    North Dakota                 98.0
# 12        Illinois                 93.0

# %%
# States based on bottom 3 participation rate in act 2017
p_act17_low
# Out:
#             state  participation_act17
# 38   Rhode Island                 21.0
# 6        Delaware                 18.0
# 28  New Hampshire                 18.0
# 18          Maine                  8.0

# %% [markdown]
# **2018 ACT**

# %%
p_act18 = actsat_1718.loc[:,['state','participation_act18']]
p_act18.head()
# Out:
#         state  participation_act18
# 0      Alaska                   33
# 1     Arizona                   66
# 2    Arkansas                  100
# 3  California                   27
# 4    Colorado                   30

# %%
# Getting the unique values for scores to find the top 3 and bottom 3 
x = np.unique(p_act18['participation_act18'])
print("top 3 participation rates are (%): ", x[-3:])
print("bottom 3 participation rates are (%): ", x[:3])

p_act18_low = p_act18[p_act18['participation_act18'] <= x[2]].sort_values(by=['participation_act18'], ascending = False)
p_act18_high = p_act18[p_act18['participation_act18'] >= x[-3]].sort_values(by=['participation_act18'], ascending = False)
# Out:
# top 3 participation rates are (%):  [ 98  99 100]
# bottom 3 participation rates are (%):  [ 7 15 16]

# %%
# States based on top 3 participation rate in act 2018
p_act18_high
# Out:
#              state  participation_act18
# 2         Arkansas                  100
# 16        Kentucky                  100
# 48       Wisconsin                  100
# 43            Utah                  100
# 41       Tennessee                  100
# 39  South Carolina                  100
# 35        Oklahoma                  100
# 34            Ohio                  100
# 32  North Carolina                  100
# 27          Nevada                  100
# 26        Nebraska                  100
# 25         Montana                  100
# 24        Missouri                  100
# 23     Mississippi                  100
# 17       Louisiana                  100
# 49         Wyoming                  100
# 22       Minnesota                   99
# 33    North Dakota                   98

# %%
# States based on bottom 3 participation rate in act 2018
p_act18_low
# Out:
#             state  participation_act18
# 28  New Hampshire                   16
# 38   Rhode Island                   15
# 18          Maine                    7

# %% [markdown]
# - Which states have the highest and lowest mean total/composite scores for the:

# %% [markdown]
# To compare scores between SAT and ACT, scores have to be normalised to a common range
#
# - Dot need as they will be on 2 different axes

# %%
# from sklearn import preprocessing

# %%
# min_max_scaler = preprocessing.MinMaxScaler()
# np_scaled = min_max_scaler.fit_transform(df)
# df_normalized = pd.DataFrame(np_scaled, columns = cols)
# df_normalized

# %%
# total_composite = actsat_1718[['total_sat17','total_sat18','composite_act17', 'composite_act18']]
# cols = total_composite.columns
# df = pd.DataFrame(total_composite)
# df.head()

# %%
# min_max_scaler = preprocessing.MinMaxScaler()
# np_scaled = min_max_scaler.fit_transform(total_composite)
# total_composite_normalised = pd.DataFrame(np_scaled, columns = cols)
# df_normalized

# %% [markdown]
# **2017 SAT**

# %%
t_sat17 = actsat_1718.loc[:,['state','total_sat17']]
t_sat17.head()
# Out:
#         state  total_sat17
# 0      Alaska         1080
# 1     Arizona         1116
# 2    Arkansas         1208
# 3  California         1055
# 4    Colorado         1201

# %%
# Getting the unique values for scores to find the top 3 and bottom 3 
x = np.unique(t_sat17['total_sat17'])
print("States with top 3 scores are: ", x[-3:])
print("States with bottom 3 scores are: ", x[:3])

t_sat17_low = t_sat17[t_sat17['total_sat17'] <= x[2]].sort_values(by=['total_sat17'], ascending = False)
t_sat17_high = t_sat17[t_sat17['total_sat17'] >= x[-3]].sort_values(by=['total_sat17'], ascending = False)
# Out:
# States with top 3 scores are:  [1275 1291 1295]
# States with bottom 3 scores are:  [ 950  996 1005]

# %%
t_sat17_low
# Out:
#                    state  total_sat17
# 11                 Idaho         1005
# 21              Michigan         1005
# 6               Delaware          996
# 7   District of Columbia          950

# %%
t_sat17_high
# Out:
#         state  total_sat17
# 22  Minnesota         1295
# 48  Wisconsin         1291
# 14       Iowa         1275

# %% [markdown]
# **2018 SAT**

# %%
t_sat18 = actsat_1718.loc[:,['state','total_sat18']]
t_sat18.head()
# Out:
#         state  total_sat18
# 0      Alaska         1106
# 1     Arizona         1149
# 2    Arkansas         1169
# 3  California         1076
# 4    Colorado         1025

# %%
# Getting the unique values for scores to find the top 3 and bottom 3 
x = np.unique(t_sat18['total_sat18'])
print("States with top 3 scores are: ", x[-3:])
print("States with bottom 3 scores are: ", x[:3])

t_sat18_low = t_sat18[t_sat18['total_sat18'] <= x[2]].sort_values(by=['total_sat18'], ascending = False)
t_sat18_high = t_sat18[t_sat18['total_sat18'] >= x[-3]].sort_values(by=['total_sat18'], ascending = False)
# Out:
# States with top 3 scores are:  [1283 1294 1298]
# States with bottom 3 scores are:  [977 998 999]

# %%
t_sat18_low
# Out:
#                    state  total_sat18
# 47         West Virginia          999
# 6               Delaware          998
# 7   District of Columbia          977

# %%
t_sat18_high
# Out:
#            state  total_sat18
# 22     Minnesota         1298
# 48     Wisconsin         1294
# 33  North Dakota         1283

# %% [markdown]
# **2017 ACT**

# %%
c_act17 = actsat_1718.loc[:,['state','composite_act17']]
c_act17.head()
# Out:
#         state  composite_act17
# 0      Alaska             19.8
# 1     Arizona             19.7
# 2    Arkansas             19.4
# 3  California             22.8
# 4    Colorado             20.8

# %%
# Getting the unique values for scores to find the top 3 and bottom 3 
x = np.unique(c_act17['composite_act17'])
print("States with top 3 scores are: ", x[-3:])
print("States with bottom 3 scores are: ", x[:3])

c_act17_low = c_act17[c_act17['composite_act17'] <= x[2]].sort_values(by=['composite_act17'], ascending = False)
c_act17_high = c_act17[c_act17['composite_act17'] >= x[-3]].sort_values(by=['composite_act17'], ascending = False)
# Out:
# States with top 3 scores are:  [25.2 25.4 25.5]
# States with bottom 3 scores are:  [17.8 18.6 18.7]

# %%
c_act17_low
# Out:
#              state  composite_act17
# 39  South Carolina             18.7
# 23     Mississippi             18.6
# 27          Nevada             17.8

# %%
c_act17_high
# Out:
#             state  composite_act17
# 28  New Hampshire             25.5
# 20  Massachusetts             25.4
# 5     Connecticut             25.2

# %% [markdown]
# **2018 ACT**

# %%
c_act18 = actsat_1718.loc[:,['state','composite_act18']]
c_act18.head()
# Out:
#         state  composite_act18
# 0      Alaska             20.8
# 1     Arizona             19.2
# 2    Arkansas             19.4
# 3  California             22.7
# 4    Colorado             23.9

# %%
# Getting the unique values for scores to find the top 3 and bottom 3 
x = np.unique(c_act18['composite_act18'])
print("States with top 3 scores are: ", x[-3:])
print("States with bottom 3 scores are: ", x[:3])

c_act18_low = c_act18[c_act18['composite_act18'] <= x[2]].sort_values(by=['composite_act18'], ascending = False)
c_act18_high = c_act18[c_act18['composite_act18'] >= x[-3]].sort_values(by=['composite_act18'], ascending = False)
# Out:
# States with top 3 scores are:  [25.1 25.5 25.6]
# States with bottom 3 scores are:  [17.7 18.3 18.6]

# %%
c_act18_low
# Out:
#              state  composite_act18
# 23     Mississippi             18.6
# 39  South Carolina             18.3
# 27          Nevada             17.7

# %%
c_act18_high
# Out:
#             state  composite_act18
# 5     Connecticut             25.6
# 20  Massachusetts             25.5
# 28  New Hampshire             25.1

# %% [markdown]
# - Do any states with 100% participation on a given test have a rate change year-to-year?

# %%
# Query for any states that had full participation in one year but not the other (2017/2018)
full_change = actsat_1718[(                                      # Assigning output to new dataframe var
        ((actsat_1718['participation_act17']==100)|(actsat_1718['participation_act18']==100)) # Include St if full ACT participation
        &                                                                           # in either year, AND
        (actsat_1718['participation_act17']!=actsat_1718['participation_act18'])          # the other year is not also full
        |                                                                           # OR
        ((actsat_1718['participation_sat17']==100)|(actsat_1718['participation_sat18']==100)) # the state had full SAT for 17 or 18
        &                                                                           # AND
        (actsat_1718['participation_sat17']!=actsat_1718['participation_sat18'])          # the other year is not also full
    )]
full_change[['state', 'participation_sat17', 'participation_sat18', 'participation_act17', #Then show relevant cols
               'participation_act18']].style.highlight_max(axis=1,color='lightblue') # Added Pandas formatting to indicate which tests were 100%
# Out:
# <style  type="text/css" >
#     #T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow0_col2 {
#             background-color:  lightblue;
#         }    #T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow0_col3 {
#             background-color:  lightblue;
#         }    #T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow1_col1 {
#             background-color:  lightblue;
#         }    #T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow2_col2 {
#             background-color:  lightblue;
#         }    #T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow3_col3 {
#             background-color:  lightblue;
#         }    #T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow4_col4 {
#             background-color:  lightblue;
#         }    #T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow5_col4 {
#             background-color:  lightblue;
#         }</style><table id="T_69afc41a_2193_11ea_bfdb_90324b88e7cc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >state</th>        <th class="col_heading level0 col1" >participation_sat17</th>        <th class="col_heading level0 col2" >participation_sat18</th>        <th class="col_heading level0 col3" >participation_act17</th>        <th class="col_heading level0 col4" >participation_act18</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_69afc41a_2193_11ea_bfdb_90324b88e7cclevel0_row0" class="row_heading level0 row0" >4</th>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow0_col0" class="data row0 col0" >Colorado</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow0_col1" class="data row0 col1" >11</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow0_col2" class="data row0 col2" >100</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow0_col3" class="data row0 col3" >100</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow0_col4" class="data row0 col4" >30</td>
#             </tr>
#             <tr>
#                         <th id="T_69afc41a_2193_11ea_bfdb_90324b88e7cclevel0_row1" class="row_heading level0 row1" >7</th>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow1_col0" class="data row1 col0" >District of Columbia</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow1_col1" class="data row1 col1" >100</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow1_col2" class="data row1 col2" >92</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow1_col3" class="data row1 col3" >32</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow1_col4" class="data row1 col4" >32</td>
#             </tr>
#             <tr>
#                         <th id="T_69afc41a_2193_11ea_bfdb_90324b88e7cclevel0_row2" class="row_heading level0 row2" >11</th>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow2_col0" class="data row2 col0" >Idaho</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow2_col1" class="data row2 col1" >93</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow2_col2" class="data row2 col2" >100</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow2_col3" class="data row2 col3" >38</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow2_col4" class="data row2 col4" >36</td>
#             </tr>
#             <tr>
#                         <th id="T_69afc41a_2193_11ea_bfdb_90324b88e7cclevel0_row3" class="row_heading level0 row3" >22</th>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow3_col0" class="data row3 col0" >Minnesota</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow3_col1" class="data row3 col1" >3</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow3_col2" class="data row3 col2" >4</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow3_col3" class="data row3 col3" >100</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow3_col4" class="data row3 col4" >99</td>
#             </tr>
#             <tr>
#                         <th id="T_69afc41a_2193_11ea_bfdb_90324b88e7cclevel0_row4" class="row_heading level0 row4" >26</th>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow4_col0" class="data row4 col0" >Nebraska</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow4_col1" class="data row4 col1" >3</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow4_col2" class="data row4 col2" >3</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow4_col3" class="data row4 col3" >84</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow4_col4" class="data row4 col4" >100</td>
#             </tr>
#             <tr>
#                         <th id="T_69afc41a_2193_11ea_bfdb_90324b88e7cclevel0_row5" class="row_heading level0 row5" >34</th>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow5_col0" class="data row5 col0" >Ohio</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow5_col1" class="data row5 col1" >12</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow5_col2" class="data row5 col2" >18</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow5_col3" class="data row5 col3" >75</td>
#                         <td id="T_69afc41a_2193_11ea_bfdb_90324b88e7ccrow5_col4" class="data row5 col4" >100</td>
#             </tr>
#     </tbody></table>

# %%
# Query for all scores of states with full participation changes
final_part_ch[['state','act_composite_2017','act_composite_2018','sat_total_2017','sat_total_2018']]

# %% [markdown]
# I am interested in
# - **Colorado (4)**: SAT participation increased significantly fromm 2017 to 2018 while ACT participation reduced significantly
#     - SAT participation rose from 11% to 100%
#     - ACT participation fell from 100% to 30%
# - **Nebraska (26)**: ACT participation rose from 84% to 100% within a year
# - **Ohio (34)**: ACT participation rose from 75% to 100% within a year

# %%
# The states with 100% participation for the SATs year-to-year experienced a slight change. Connecticut, Michigan and Delaware remained at 100%. Idaho and Colorado achived 100% in 2018 while the District of Columbia only mananged 100% in 2017

# %% [markdown]
# - Do any states show have >50% participation on *both* tests either year?

# %%
# To show states that have more than 50% participation in both tests in 2017
p_actsat17 = actsat_1718[['state','participation_sat17','participation_act17']]
p_actsat17
p_actsat17[(p_actsat17['participation_sat17'] > 50) & (p_actsat17.participation_act17 > 50)]
# Out:
#       state  participation_sat17  participation_act17
# 8   Florida                 83.0                 73.0
# 9   Georgia                 61.0                 55.0
# 10   Hawaii                 55.0                 90.0

# %%
# To show states that have more than 50% participation in both tests in 2018
p_actsat18 = actsat_1718[['state','participation_sat18','participation_act18']]
p_actsat18
p_actsat18[(p_actsat18['participation_sat18'] > 50) & (p_actsat18.participation_act18 > 50)]
# Out:
#              state  participation_sat18  participation_act18
# 8          Florida                 56.0                   66
# 9          Georgia                 70.0                   53
# 10          Hawaii                 56.0                   89
# 32  North Carolina                 52.0                  100
# 39  South Carolina                 55.0                  100

# %% [markdown]
# Take note of any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.

# %% [markdown]
# ## Visualize the data

# %% [markdown]
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding

# %%
sns.set(font_scale=0.75)
plt.figure(figsize=(12,12))
sns.heatmap(actsat_1718.corr(), annot = True);
plt.title("Heatmap to visualise how correlated our dataset is", fontsize=15);

# %% [markdown]
# #### Define a custom function to subplot histograms

# %%
# Given
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    #plt.figure(figsize=(15,15))
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize = (12,12)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        # Set titles, labels, etc here for each subplot
        ax[i].set_title(list_of_titles[i],fontsize=15)
        ax[i].set_xlabel(list_of_xlabels[i],fontsize=12)
        ax[i].set_ylabel('Number of States',fontsize=12)

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:

# %% [markdown]
# - Participation rates for SAT & ACT

# %%
participation_columns = ['participation_sat17','participation_sat18',
                   'participation_act17','participation_act18']
list_of_titles = ['SAT 2017','SAT 2018','ACT 2017','ACT 2018']

list_of_xlabels = [i for i in participation_columns]  

subplot_histograms(actsat_1718, participation_columns, list_of_titles,list_of_xlabels)

# %% [markdown]
# - Math scores for SAT & ACT

# %%
math_columns = ['math_sat17','math_sat18',
                   'math_act17','math_act18']
list_of_titles = ['SAT 2017','SAT 2018','ACT 2017','ACT 2018']

list_of_xlabels = [i for i in math_columns]  

subplot_histograms(actsat_1718, math_columns, list_of_titles,list_of_xlabels)

# %% [markdown]
# - Reading/verbal scores for SAT & ACT

# %%
actsat_1718.head()
# Out:
#         state  participation_sat17  ebrw_sat17  math_sat17  total_sat17  \
# 0      Alaska                 38.0         547         533         1080
# 1     Arizona                 30.0         563         553         1116
# 2    Arkansas                  3.0         614         594         1208
# 3  California                 53.0         531         524         1055
# 4    Colorado                 11.0         606         595         1201
#
#    participation_act17  english_act17  math_act17  reading_act17  \
# 0                 65.0           18.7        19.8           20.4
# 1                 62.0           18.6        19.8           20.1
# 2                100.0           18.9        19.0           19.7
# 3                 31.0           22.5        22.7           23.1
# 4                100.0           20.1        20.3           21.2
#
#    science_act17  ...  participation_sat18  ebrw_sat18  math_sat18  \
# 0           19.9  ...                 43.0         562         544
# 1           19.8  ...                 29.0         577         572
# 2           19.5  ...                  5.0         592         576
# 3           22.2  ...                 60.0         540         536
# 4           20.9  ...                100.0         519         506
#
#    total_sat18  participation_act18  english_act18  math_act18  reading_act18  \
# 0         1106                   33           19.8        20.6           21.6
# 1         1149                   66           18.2        19.4           19.5
# 2         1169                  100           19.1        18.9           19.7
# 3         1076                   27           22.5        22.5           23.0
# 4         1025                   30           23.9        23.2           24.4
#
#    science_act18  composite_act18
# 0           20.7             20.8
# 1           19.2             19.2
# 2           19.4             19.4
# 3           22.1             22.7
# 4           23.5             23.9
#
# [5 rows x 21 columns]

# %%
reading_columns = ['ebrw_sat17','ebrw_sat18',
                   'reading_act17','reading_act18']
list_of_titles = ['SAT 2017','SAT 2018','ACT 2017','ACT 2018']

list_of_xlabels = [i for i in reading_columns]  

subplot_histograms(actsat_1718, reading_columns, list_of_titles,list_of_xlabels)

# %% [markdown]
# #### Plot and interpret scatter plots
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
def subplot_scatter(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    ax = plt.subplots(figsize = (8,8))
    for i, col in enumerate(list_of_columns):
        sns.regplot

# %% [markdown]
# - SAT vs. ACT math scores for 2017

# %%
ax = plt.subplots(figsize=(8,8))
ax = sns.regplot(y='math_sat17', x='math_act17', data=actsat_1718[['math_sat17','math_act17']])
#ax = sns.scatterplot(y='math_sat17', x='math_act17', data=actsat_1718[['math_sat17','math_act17']])
ax.set_title('SAT vs ACT Math Scores 2017\n(Relationship between the two scores)',fontsize=15)
ax.set_xlabel('ACT Math 2017',fontsize=12)
ax.set_ylabel('SAT Math 2017',fontsize=12)
# Out:
# Text(0, 0.5, 'SAT Math 2017')

# %% [markdown]
# - SAT vs. ACT verbal/reading scores for 2017

# %%
ax = plt.subplots(figsize=(8,8))
ax = sns.regplot(y='ebrw_sat17', x='reading_act17', data=actsat_1718[['ebrw_sat17','reading_act17']])
#ax = sns.regplot(y='ebrw_sat17', x='reading_act17', data=actsat_1718[['ebrw_sat17','reading_act17']])
ax.set_title('SAT vs ACT Verbal/reading Scores 2017\n(Relationship between the two scores)',fontsize=15)
ax.set_xlabel('ACT Reading 2017',fontsize=12)
ax.set_ylabel('SAT Evidence based Reading Writing 2017',fontsize=12)
# Out:
# Text(0, 0.5, 'SAT Evidence based Reading Writing 2017')

# %% [markdown]
# - SAT vs. ACT total/composite scores for 2017

# %%
ax = plt.subplots(figsize=(8,8))
ax = sns.regplot(y='total_sat17', x='composite_act17', data=actsat_1718[['total_sat17','composite_act17']])
#ax = sns.regplot(y='total_sat17', x='composite_act17', data=actsat_1718[['total_sat17','composite_act17']])
ax.set_title('SAT vs ACT Total/Composite Scores 2017\n(Relationship between the two scores)',fontsize=15)
ax.set_xlabel('ACT Composite 2017',fontsize=12)
ax.set_ylabel('SAT Total 2017',fontsize=12)
# Out:
# Text(0, 0.5, 'SAT Total 2017')

# %% [markdown]
# - Total scores for SAT 2017 vs. 2018

# %%
ax = plt.subplots(figsize=(8,8))
ax = sns.regplot(y='total_sat17', x='total_sat18', data=actsat_1718[['total_sat17','total_sat18']])
#ax = sns.regplot(y='total_sat17', x='composite_act17', data=actsat_1718[['total_sat17','composite_act17']])
ax.set_title('SAT Total Scores 2017 vs 2018\n(Relationship between the two scores)',fontsize=15)
ax.set_xlabel('SAT Total 2018',fontsize=12)
ax.set_ylabel('SAT Total 2017',fontsize=12)
# Out:
# Text(0, 0.5, 'SAT Total 2017')

# %% [markdown]
# - Composite scores for ACT 2017 vs. 2018

# %%
ax = plt.subplots(figsize=(8,8))
ax = sns.regplot(y='composite_act17', x='composite_act18', data=actsat_1718[['composite_act17','composite_act18']])
#ax = sns.regplot(y='total_sat17', x='composite_act17', data=actsat_1718[['total_sat17','composite_act17']])
ax.set_title('ACT Composite Scores 2017 vs 2018\n(Relationship between the two scores)',fontsize=15)
ax.set_xlabel('ACT Composite 2018',fontsize=12)
ax.set_ylabel('ACT Conposite 2017',fontsize=12)
# Out:
# Text(0, 0.5, 'ACT Conposite 2017')

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %% [markdown]
# - SAT Scores

# %%
ax = plt.subplots(figsize=(12,10))
#ax = sns.boxplot(actsat_1718[['ebrw_sat17','ebrw_sat18','math_sat17','math_sat18']])
sns.boxplot(data=actsat_1718[['ebrw_sat17','ebrw_sat18','math_sat17','math_sat18']],width=0.4)
plt.title('SAT Scores 2017 & 2018',fontsize=15)
plt.ylabel('Score',fontsize=12)
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# - ACT Scores (2017)

# %%
actsat_1718.columns
# Out:
# Index(['state', 'participation_sat17', 'ebrw_sat17', 'math_sat17',
#        'total_sat17', 'participation_act17', 'english_act17', 'math_act17',
#        'reading_act17', 'science_act17', 'composite_act17',
#        'participation_sat18', 'ebrw_sat18', 'math_sat18', 'total_sat18',
#        'participation_act18', 'english_act18', 'math_act18', 'reading_act18',
#        'science_act18', 'composite_act18'],
#       dtype='object')

# %%
ax = plt.subplots(figsize=(12,10))
#ax = sns.boxplot(actsat_1718[['ebrw_sat17','ebrw_sat18','math_sat17','math_sat18']])
sns.boxplot(data=actsat_1718[['english_act17', 'math_act17',
       'reading_act17', 'science_act17']],width=0.4)
plt.title('ACT Scores 2017',fontsize=15)
plt.ylabel('Score',fontsize=12)
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# - ACT Scores (2018)

# %%
ax = plt.subplots(figsize=(12,10))
#ax = sns.boxplot(actsat_1718[['ebrw_sat17','ebrw_sat18','math_sat17','math_sat18']])
sns.boxplot(data=actsat_1718[['english_act18', 'math_act18',
       'reading_act18', 'science_act18']],width=0.4)
plt.title('ACT Scores 2018',fontsize=15)
plt.ylabel('Score',fontsize=12)
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# - ACT Scores (2017 and 2018)

# %%
ax = plt.subplots(figsize=(12,10))
#ax = sns.boxplot(actsat_1718[['ebrw_sat17','ebrw_sat18','math_sat17','math_sat18']])
sns.boxplot(data=actsat_1718[['english_act17', 'math_act17',
       'reading_act17', 'science_act17','english_act18', 'math_act18',
       'reading_act18', 'science_act18']],width=0.4)
plt.title('ACT Scores',fontsize=15)
plt.ylabel('Score',fontsize=12)
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# - Participation rates for SAT and ACT (2017, 2018)

# %%
ax = plt.subplots(figsize=(12,10))
#ax = sns.boxplot(actsat_1718[['ebrw_sat17','ebrw_sat18','math_sat17','math_sat18']])
sns.boxplot(data=actsat_1718[['participation_sat17', 'participation_sat18',
       'participation_act17', 'participation_act18']],width=0.4)
plt.title('Participation rates for SAT and ACT 2017, 2018',fontsize=15)
plt.ylabel('Score',fontsize=12)
plt.ylim(0,120)
# Out:
# (0, 120)

# %% [markdown]
# - Total/Composite scores for SAT and ACT (2017, 2018)

# %%
ax = plt.subplots(figsize=(12,10))
ax1 = plt.subplot(211)
ax1.set_title("Total scores for SAT 2017, 2018", loc = "left", fontsize = 12)
ax1 = sns.boxplot(data=actsat_1718[['total_sat17', 'total_sat18']],width=0.4)
ax1 = plt.ylabel('Score',fontsize=12)

ax2 = plt.subplot(212)
ax2.set_title("Composite scores for ACT 2017, 2018", loc = "left", fontsize = 12)
ax2 = sns.boxplot(data=actsat_1718[['composite_act17', 'composite_act18']],width=0.4)
#plt.title('Total/Composite scores for SAT and ACT 2017, 2018',fontsize=15)
ax2 = plt.ylabel('Score',fontsize=12)

# %%
# fig_sat = heatmap(actsat_1718_heat,"participation_SAT17", 'SAT Participation Rate by State', scl)
# py.iplot( fig_sat, filename='d3-cloropleth-map' )

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
actsat_1718.columns
# Out:
# Index(['state', 'participation_sat17', 'ebrw_sat17', 'math_sat17',
#        'total_sat17', 'participation_act17', 'english_act17', 'math_act17',
#        'reading_act17', 'science_act17', 'composite_act17',
#        'participation_sat18', 'ebrw_sat18', 'math_sat18', 'total_sat18',
#        'participation_act18', 'english_act18', 'math_act18', 'reading_act18',
#        'science_act18', 'composite_act18'],
#       dtype='object')

# %%
# g = sns.pairplot(actsat_1718[['participation_sat17', 'ebrw_sat17', 'math_sat17',
#        'total_sat17', 'participation_sat18', 'ebrw_sat18', 'math_sat18', 'total_sat18']])
# g.fig.suptitle("Summary for SAT", y = 1.02, fontsize = 20)

# %%
# g = sns.pairplot(actsat_1718[['participation_act17', 'english_act17', 'math_act17',
#        'reading_act17', 'science_act17', 'composite_act17']])
# g.fig.suptitle("Summary for ACT 2017", y = 1.02, fontsize = 20)

# %%
actsat_1718.describe()
# Out:
#        participation_sat17  ebrw_sat17  math_sat17  total_sat17  \
# count            50.000000   50.000000   50.000000    50.000000
# mean             40.500000  568.640000  556.580000  1125.320000
# std              35.279207   46.001668   47.549798    93.265134
# min               2.000000  482.000000  468.000000   950.000000
# 25%               4.000000  532.750000  523.250000  1055.250000
# 50%              40.500000  558.500000  544.500000  1104.500000
# 75%              66.500000  613.500000  601.000000  1214.000000
# max             100.000000  644.000000  651.000000  1295.000000
#
#        participation_act17  english_act17  math_act17  reading_act17  \
# count            50.000000       50.00000   50.000000      50.000000
# mean             64.560000       20.97200   21.238000      22.060000
# std              32.077814        2.35944    1.961454       2.061404
# min               8.000000       16.30000   18.000000      18.100000
# 25%              31.000000       19.10000   19.500000      20.500000
# 50%              68.000000       20.80000   21.050000      21.850000
# 75%             100.000000       23.30000   23.100000      24.175000
# max             100.000000       25.50000   25.300000      26.000000
#
#        science_act17  composite_act17  participation_sat18  ebrw_sat18  \
# count      50.000000        50.000000            50.000000    50.00000
# mean       21.492000        21.566000            46.540000   563.06000
# std         1.731914         2.013588            37.254344    47.77174
# min        18.200000        17.800000             2.000000   480.00000
# 25%        20.025000        19.850000             4.250000   534.25000
# 50%        21.400000        21.400000            53.500000   551.00000
# 75%        23.200000        23.600000            78.250000   612.75000
# max        24.900000        25.500000           100.000000   643.00000
#
#        math_sat18  total_sat18  participation_act18  english_act18  \
# count   50.000000    50.000000            50.000000      50.000000
# mean   555.940000  1119.100000            60.880000      21.030000
# std     48.210597    94.879354            33.979369       2.452758
# min    480.000000   977.000000             7.000000      16.600000
# 25%    522.250000  1055.250000            27.750000      19.125000
# 50%    543.500000  1096.000000            65.500000      20.400000
# 75%    594.250000  1207.000000           100.000000      23.700000
# max    655.000000  1298.000000           100.000000      26.000000
#
#        math_act18  reading_act18  science_act18  composite_act18
# count   50.000000      50.000000      50.000000        50.000000
# mean    21.182000      22.064000      21.392000        21.534000
# std      2.015622       2.161326       1.858553         2.099622
# min     17.800000      18.000000      17.900000        17.700000
# 25%     19.475000      20.525000      20.000000        20.000000
# 50%     20.800000      21.650000      21.250000        21.300000
# 75%     23.175000      24.150000      23.075000        23.575000
# max     25.200000      26.100000      24.900000        25.600000

# %% [markdown]
# - The sample variance, s2, is a popular measure of dispersion. It is an average of the squared deviations from the mean.
# - The standard error of the mean, a measure of the variation of the sample mean about the population mean, is computed by dividing the sample standard deviation by the square root of the sample size.
# - 95% Confidence Interval for the Mean (95% LCL & 95% UCL)
#     - This is the upper and lower values of a 95% confidence interval estimate for the mean based on a t distribution with n – 1 degrees of freedom. This interval estimate assumes that the population standard deviation is not known and that the data for this variable are normally distributed.
# - Range: The difference between the largest and smallest data values.
# - Skewness: Measures the direction and degree of asymmetry in the data distribution.
# - Kurtosis: Measures the heaviness of the tails in the data distribution.

# %%
# The center, the shape, and the spread.
mu=pd.Series(actsat_1718.mean(), name="mean")
std = pd.Series(actsat_1718.std(), name="std_dev")
m_s = pd.concat([mu,std], axis=1)
m_s.sort_values('std_dev').head()
# Out:
#                    mean   std_dev
# science_act17    21.492  1.731914
# science_act18    21.392  1.858553
# math_act17       21.238  1.961454
# composite_act17  21.566  2.013588
# math_act18       21.182  2.015622

# %%
fig, ax = subplot_histograms(actsat_1718,actsat_1718.columns.tolist()[1:-1],[1,2,3,4],'Full Summary Distribution Snapshot')
plt.subplots_adjust(top=0.96)
plt.show(); # call subplot_histograms function for distribution snapshot
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-184-ec6db4f0f80b> in <module>
# ----> 1 fig, ax = subplot_histograms(actsat_1718,actsat_1718.columns.tolist()[1:-1],[1,2,3,4],'Full Summary Distribution Snapshot')
#       2 plt.subplots_adjust(top=0.96)
#       3 plt.show(); # call subplot_histograms function for distribution snapshot
#
# <ipython-input-56-437d75334d5c> in subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels)
#       8         ax[i].hist(dataframe[column]) # feel free to add more settings
#       9         # Set titles, labels, etc here for each subplot
# ---> 10         ax[i].set_title(list_of_titles[i],fontsize=15)
#      11         ax[i].set_xlabel(list_of_xlabels[i],fontsize=12)
#      12         ax[i].set_ylabel('Number of States',fontsize=12)
#
# IndexError: list index out of range

# %% [markdown]
# The distributions of the scores and participation rates are not normal and not close to uniform. I would like to have more data.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?
